# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
# Out:
# /home/choct155/analysis/Anaconda/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module argparse was already imported from /home/choct155/analysis/Anaconda/lib/python2.7/argparse.pyc, but /home/choct155/analysis/Anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
workdir='/home/choct155/Documents/'
stmt=pd.read_csv(workdir+'stmt.csv',error_bad_lines=False)
stmt
# Out:
# Skipping line 18: expected 1 fields, saw 2
# Skipping line 34: expected 1 fields, saw 2
# Skipping line 76: expected 1 fields, saw 2
# Skipping line 119: expected 1 fields, saw 2
# Skipping line 144: expected 1 fields, saw 2
# Skipping line 177: expected 1 fields, saw 2
# Skipping line 196: expected 1 fields, saw 2
# Skipping line 220: expected 1 fields, saw 2
# Skipping line 239: expected 1 fields, saw 2
# Skipping line 248: expected 1 fields, saw 2
# Skipping line 259: expected 1 fields, saw 2
# Skipping line 272: expected 1 fields, saw 2
#               Date\tDescription\tAmount\tRunning Bal.
# 0   03/02/2013\tBeginning balance as of 03/02/2013...
# 1   03/04/2013\tCHECKCARD 0301 CITYPAWS INC WASHIN...
# 2   03/04/2013\tWELLS FARGO FINANCIAL NATIONAL B B...
# 3   03/04/2013\tCHECKCARD 0301 CITYPAWS INC WASHIN...
# 4   03/04/2013\tCHECKCARD 0301 DC PARKING www.park...
# 5   03/04/2013\tKEEP THE CHANGE TRANSFER TO ACCT 5...
# 6   03/07/2013\tOnline Banking transfer from CHK 9...
# ...
