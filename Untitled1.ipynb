# %%
import pyproj
help(pyproj)
# Out:
# Help on package pyproj:
#
# NAME
#     pyproj
#
# FILE
#     /home/choct155/analysis/Anaconda/lib/python2.7/site-packages/pyproj/__init__.py
#
# DESCRIPTION
#     Cython wrapper to provide python interfaces to
#     PROJ.4 (http://trac.osgeo.org/proj/) functions.
#
#     Performs cartographic transformations and geodetic computations.
#
#     The Proj class can convert from geographic (longitude,latitude)
#     to native map projection (x,y) coordinates and vice versa, or
#     from one map projection coordinate system directly to another.
#     The module variable pj_list is a dictionary containing all the
#     available projections and their descriptions.
#
#     The Geod class can perform forward and inverse geodetic, or
#     Great Circle, computations.  The forward computation involves
#     determining latitude, longitude and back azimuth of a terminus
#     point given the latitude and longitude of an initial point, plus
# ...

# %%
from kartograph import Kartograph
K = Kartograph()

nbhds={"layers": [{"id":"mylayer",
                   "src": "/home/choct155/ora_public/dc_shp/CompPlanPlanningAreas.shp"
                   }],
       "proj":{"id":"proj4",
               "opts":"+proj=merc +a=6378137 +b=6378137 +lat_ts=0.0 +lon_0=0.0 +x_0=0.0 +y_0=0 +k=1.0 +units=m +nadgrids=@null +wktext  +no_defs"
               }
       }

K.generate(nbhds, outfile='nbhds.svg')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-b305073cb744> in <module>()
#      10        }
#      11
# ---> 12 K.generate(nbhds, outfile='nbhds.svg')
#
# /home/choct155/analysis/Anaconda/lib/python2.7/site-packages/kartograph/kartograph.pyc in generate(self, opts, outfile, format, preview, stylesheet)
#      44         # definitely should check out [map.py](map.html) for all the fun stuff happending
#      45         # there..
# ---> 46         _map = Map(opts, self.layerCache, format=format)
#      47
#      48         # Check if the format is handled by a renderer.
#
# /home/choct155/analysis/Anaconda/lib/python2.7/site-packages/kartograph/map.pyc in __init__(me, options, layerCache, format, src_encoding)
#      40         for layer_cfg in options['layers']:
#      41             layer_id = layer_cfg['id']
# ...

# %%
help(K.generate)
# Out:
# Help on method generate in module kartograph.kartograph:
#
# generate(self, opts, outfile=None, format='svg', preview=None, stylesheet=None) method of kartograph.kartograph.Kartograph instance
#     Generates a the map and renders it using the specified output format.

# %%
from kartograph import Kartograph
K = Kartograph()

world={"layers": [{"id":"mylayer",
                   "src": "/home/choct155/analysis/kartograph-test/ne_50m_admin_0_countries.shp"
                   }],
       "proj":{"id":"mercator"
               }
       }

K.generate(world, outfile='world.svg')

# %%
states={"layers": [{"id":"mylayer",
                   "src": "/home/choct155/ora_public/dc_shp/Google_CensusBG_Areas.shp"
                   }],
       "proj":{"id":"mercator"
               }
       }

K.generate(states, outfile='DC_nbhds.svg')
